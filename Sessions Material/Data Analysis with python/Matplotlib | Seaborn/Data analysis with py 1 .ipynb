# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Starting and Exploring

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.dropna()
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.describe().T
# Out:
#                 count           mean            std     min        25%  \
# price          4600.0  551962.988473  563834.702547     0.0  322875.00
# bedrooms       4600.0       3.400870       0.908848     0.0       3.00
# bathrooms      4600.0       2.160815       0.783781     0.0       1.75
# sqft_living    4600.0    2139.346957     963.206916   370.0    1460.00
# sqft_lot       4600.0   14852.516087   35884.436145   638.0    5000.75
# floors         4600.0       1.512065       0.538288     1.0       1.00
# waterfront     4600.0       0.007174       0.084404     0.0       0.00
# view           4600.0       0.240652       0.778405     0.0       0.00
# condition      4600.0       3.451739       0.677230     1.0       3.00
# sqft_above     4600.0    1827.265435     862.168977   370.0    1190.00
# sqft_basement  4600.0     312.081522     464.137228     0.0       0.00
# yr_built       4600.0    1970.786304      29.731848  1900.0    1951.00
# ...

# %%
(df.price == 0).sum()
# Out:
# 49

# %%
df['price'].replace(0, np.nan, inplace = True)

# %%
df.isnull().sum()
# Out:
# date              0
# price            49
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# street            0
# city              0
# statezip          0
# country           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#         date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-05-02   313000.0       3.0       1.50         1340      7912     1.5
# 1 2014-05-02  2384000.0       5.0       2.50         3650      9050     2.0
# 2 2014-05-02   342000.0       3.0       2.00         1930     11947     1.0
# 3 2014-05-02   420000.0       3.0       2.25         2000      8030     1.0
# 4 2014-05-02   550000.0       4.0       2.50         1940     10500     1.0
#
#    waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3        1340              0      1955
# 1           0     4          5        3370            280      1921
# 2           0     0          4        1930              0      1966
# 3           0     0          4        1000           1000      1963
# 4           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4551 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4551 non-null   datetime64[ns]
#  1   price          4551 non-null   float64
#  2   bedrooms       4551 non-null   float64
#  3   bathrooms      4551 non-null   float64
#  4   sqft_living    4551 non-null   int64
#  5   sqft_lot       4551 non-null   int64
#  6   floors         4551 non-null   float64
#  7   waterfront     4551 non-null   int64
#  8   view           4551 non-null   int64
#  9   condition      4551 non-null   int64
#  10  sqft_above     4551 non-null   int64
#  11  sqft_basement  4551 non-null   int64
#  12  yr_built       4551 non-null   int64
#  13  yr_renovated   4551 non-null   int64
#  14  street         4551 non-null   object
#  15  city           4551 non-null   object
#  16  statezip       4551 non-null   object
# ...

# %%
df.insert(1, "year", df.date.dt.year)
df.head()
# Out:
#         date  year      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0 2014-05-02  2014   313000.0       3.0       1.50         1340      7912
# 1 2014-05-02  2014  2384000.0       5.0       2.50         3650      9050
# 2 2014-05-02  2014   342000.0       3.0       2.00         1930     11947
# 3 2014-05-02  2014   420000.0       3.0       2.25         2000      8030
# 4 2014-05-02  2014   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.nunique(axis = 0)
# Out:
# date               70
# year                1
# price            1740
# bedrooms           10
# bathrooms          26
# sqft_living       561
# sqft_lot         3087
# floors              6
# waterfront          2
# view                5
# condition           5
# sqft_above        510
# sqft_basement     207
# yr_built          115
# yr_renovated       59
# street           4476
# city               44
# statezip           77
# country             1
# dtype: int64

# %% [markdown]
# # Understanding and Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4551 entries, 0 to 4599
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4551 non-null   datetime64[ns]
#  1   year           4551 non-null   int64
#  2   price          4551 non-null   float64
#  3   bedrooms       4551 non-null   float64
#  4   bathrooms      4551 non-null   float64
#  5   sqft_living    4551 non-null   int64
#  6   sqft_lot       4551 non-null   int64
#  7   floors         4551 non-null   float64
#  8   waterfront     4551 non-null   int64
#  9   view           4551 non-null   int64
#  10  condition      4551 non-null   int64
#  11  sqft_above     4551 non-null   int64
#  12  sqft_basement  4551 non-null   int64
#  13  yr_built       4551 non-null   int64
#  14  yr_renovated   4551 non-null   int64
#  15  street         4551 non-null   object
#  16  city           4551 non-null   object
# ...

# %%
df['year'].value_counts()
# Out:
# 2014    4551
# Name: year, dtype: int64

# %%
df['bedrooms'].value_counts()
# Out:
# 3.0    2025
# 4.0    1512
# 2.0     561
# 5.0     338
# 6.0      59
# 1.0      37
# 7.0      14
# 0.0       2
# 8.0       2
# 9.0       1
# Name: bedrooms, dtype: int64

# %%
df['bedrooms'] = df['bedrooms'].astype('int')

# %%
df['bedrooms'].value_counts()
# Out:
# 3    2025
# 4    1512
# 2     561
# 5     338
# 6      59
# 1      37
# 7      14
# 0       2
# 8       2
# 9       1
# Name: bedrooms, dtype: int64

# %%
sns.countplot(x=df["bedrooms"])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
df['bathrooms'] = df['bathrooms'].astype('int')

# %%
df['bathrooms'].value_counts()
# Out:
# 2    2292
# 1    1654
# 3     492
# 4      76
# 0      19
# 5      14
# 6       3
# 8       1
# Name: bathrooms, dtype: int64

# %%
sns.countplot(x=df["bathrooms"])
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='count'>

# %%
df['sqft_living'].value_counts()
# Out:
# 1940    32
# 1720    32
# 1660    31
# 1840    31
# 1410    29
#         ..
# 2495     1
# 8670     1
# 4580     1
# 490      1
# 4070     1
# Name: sqft_living, Length: 561, dtype: int64

# %%
sns.countplot(x=df["sqft_living"])
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='count'>

# %%
df["sqft_living"].plot.hist(grid=True, bins=49, rwidth=0.9,color='#607c8e')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
fig = sns.kdeplot(df['sqft_living'], shade=True, color="r")

# %%
fig = sns.kdeplot(df['sqft_lot'], shade=True, color="b")

# %%
df['sqft_lot'].describe()
# Out:
# count    4.551000e+03
# mean     1.483528e+04
# std      3.596408e+04
# min      6.380000e+02
# 25%      5.000000e+03
# 50%      7.680000e+03
# 75%      1.097800e+04
# max      1.074218e+06
# Name: sqft_lot, dtype: float64

# %%
df['sqft_lot'].max()
# Out:
# 1074218

# %%
df['sqft_lot'].min()
# Out:
# 638

# %%
df['floors'].value_counts()
# Out:
# 1.0    2151
# 2.0    1791
# 1.5     439
# 3.0     127
# 2.5      41
# 3.5       2
# Name: floors, dtype: int64

# %%
sns.countplot(x=df["floors"])
# Out:
# <AxesSubplot:xlabel='floors', ylabel='count'>

# %%
df['waterfront'].value_counts()
# Out:
# 0    4521
# 1      30
# Name: waterfront, dtype: int64

# %%
sns.countplot(x=df["waterfront"])
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='count'>

# %%
plt.style.use("seaborn")
fig, ax = plt.subplots(figsize=(5,5))
plt.pie(x=df["waterfront"].value_counts(), 
      #  colors=["skyblue","pink"], 
        labels=["Yes","No"], 
        shadow = True, 
        autopct="%1.2f%%", 
        explode = (0, 0.1)
        )
plt.show()

# %%
df['view'].value_counts()
# Out:
# 0    4103
# 2     201
# 3     115
# 1      69
# 4      63
# Name: view, dtype: int64

# %%
plt.style.use("seaborn")
fig, ax = plt.subplots(figsize=(5,5))
plt.pie(x=df["view"].value_counts(), 
      #  colors=["skyblue","pink"], 
        labels=[0,2,3,1,4], 
        shadow = True, 
        autopct="%1.2f%%", 
      explode = (.2, 0.2,.2,.2,.)
        )
plt.show()

# %%
df['condition'].value_counts()
# Out:
# 3    2851
# 4    1238
# 5     425
# 2      31
# 1       6
# Name: condition, dtype: int64

# %%
sns.countplot(x=df["condition"])
# Out:
# <AxesSubplot:xlabel='condition', ylabel='count'>

# %%
df['street'].value_counts()
# Out:
# 2520 Mulberry Walk NE       4
# 2500 Mulberry Walk NE       3
# 1018 NE 96th St             2
# 13820 NE 72nd Pl            2
# Indian Trail                2
#                            ..
# 3763 SW Hinds St            1
# 11526 NE 116th St           1
# 12115 Big Leaf Way NE       1
# 1256 SW 146th St            1
# 18201-18223 114th Ave SE    1
# Name: street, Length: 4476, dtype: int64

# %%
df['city'].value_counts()
# Out:
# Seattle                1561
# Renton                  291
# Bellevue                281
# Redmond                 235
# Kirkland                187
# Issaquah                186
# Kent                    184
# Auburn                  175
# Sammamish               171
# Federal Way             145
# Shoreline               123
# Woodinville             114
# Maple Valley             95
# Mercer Island            82
# Burien                   72
# Snoqualmie               69
# Kenmore                  65
# Des Moines               58
# North Bend               50
# Covington                42
# Duvall                   42
# Lake Forest Park         34
# Bothell                  33
# Newcastle                33
# Vashon                   29
# Tukwila                  29
# SeaTac                   28
# Enumclaw                 27
# Carnation                22
# Normandy Park            17
# Medina                   11
# Fall City                11
# Clyde Hill                9
# ...

# %%
plt.figure(figsize=(30,10))
sns.countplot(x=df["city"])
# Out:
# <AxesSubplot:xlabel='city', ylabel='count'>

# %%
df['yr_built'].value_counts()
# Out:
# 2006    109
# 2005    103
# 2007     92
# 2004     92
# 1978     90
#        ...
# 1915      6
# 1935      6
# 1933      5
# 1934      4
# 1936      3
# Name: yr_built, Length: 115, dtype: int64

# %%
df["yr_built"].plot.hist(grid=True, bins=49, rwidth=0.9,color='#607c8e')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
fig = sns.kdeplot(df['yr_built'], shade=True, color="b")

# %%
sns.countplot(x = df['country'])
# Out:
# <AxesSubplot:xlabel='country', ylabel='count'>

# %%
df['country'].value_counts()
# Out:
# USA    4551
# Name: country, dtype: int64

# %%
df["price"].plot.hist(grid=True, bins=49, rwidth=0.9,color='#607c8e')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['price'].describe()
# Out:
# count    4.551000e+03
# mean     5.579059e+05
# std      5.639299e+05
# min      7.800000e+03
# 25%      3.262643e+05
# 50%      4.650000e+05
# 75%      6.575000e+05
# max      2.659000e+07
# Name: price, dtype: float64

# %%
df['price'].min(),df['price'].max()
# Out:
# (7800.0, 26590000.0)

# %%
df['price'].mean()
# Out:
# 557905.8991379443

# %%
df = df[(df['price'] <1000000 )]

# %%
df["price"].plot.hist(grid=True, bins=49, rwidth=0.9,color='#607c8e')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
fig = sns.kdeplot(df['price'], shade=True, color="y")

# %% [markdown]
# # Advanced EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4207 entries, 0 to 4599
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4207 non-null   datetime64[ns]
#  1   year           4207 non-null   int64
#  2   price          4207 non-null   float64
#  3   bedrooms       4207 non-null   int32
#  4   bathrooms      4207 non-null   int32
#  5   sqft_living    4207 non-null   int64
#  6   sqft_lot       4207 non-null   int64
#  7   floors         4207 non-null   float64
#  8   waterfront     4207 non-null   int64
#  9   view           4207 non-null   int64
#  10  condition      4207 non-null   int64
#  11  sqft_above     4207 non-null   int64
#  12  sqft_basement  4207 non-null   int64
#  13  yr_built       4207 non-null   int64
#  14  yr_renovated   4207 non-null   int64
#  15  street         4207 non-null   object
#  16  city           4207 non-null   object
# ...

# %%
plt.figure(figsize = (20,10))
ax2 = sns.countplot(hue="bathrooms", x='bedrooms', data=df )
ax2.set_ylabel("Count", fontsize=17)
plt.show()

# %%
plt.figure(figsize = (20,10))
ax2 = sns.countplot(hue="view", x='bedrooms', data=df )
ax2.set_ylabel("Count", fontsize=17)
plt.show()

# %%
plt.figure(figsize = (20,10))
ax2 = sns.countplot(hue="floors", x='bedrooms', data=df )
ax2.set_ylabel("Count", fontsize=17)
plt.show()

# %%
fig1 = sns.kdeplot(df['sqft_living'], shade=True, color="r")
fig2 = sns.kdeplot(df[df['sqft_lot']<20000]['sqft_lot'], shade=True, color="b")

# %%
df["sqft_living"].plot.hist(grid=True, bins=49, rwidth=0.9,color='#607c8e')
df[df['sqft_lot']<20000]['sqft_lot'].plot.hist(grid=True, bins=49, rwidth=0.9)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Feature Corrlation with Target

# %%
df.corr()
# Out:
#                year     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# year            NaN       NaN       NaN        NaN          NaN       NaN
# price           NaN  1.000000  0.305046   0.405898     0.607379  0.083435
# bedrooms        NaN  0.305046  1.000000   0.461920     0.603655  0.048548
# bathrooms       NaN  0.405898  0.461920   1.000000     0.637117  0.067836
# sqft_living     NaN  0.607379  0.603655   0.637117     1.000000  0.176961
# sqft_lot        NaN  0.083435  0.048548   0.067836     0.176961  1.000000
# floors          NaN  0.272151  0.148377   0.463032     0.325647 -0.010962
# waterfront      NaN  0.073671 -0.032263   0.014646     0.030473  0.026086
# view            NaN  0.196460  0.060074   0.097951     0.184432  0.085821
# condition       NaN  0.044926  0.015105  -0.144226    -0.086310  0.005033
# sqft_above      NaN  0.517395  0.466683   0.573858     0.848312  0.175447
# sqft_basement   NaN  0.221384  0.303413   0.177618     0.370693  0.021171
# ...

# %%
f, ax = plt.subplots(figsize=(8,8))
ax = sns.heatmap(df.corr(), annot=True, fmt='.1g', cmap="viridis", cbar=True)

# %%
df.corr()['price']
# Out:
# year                  NaN
# price            1.000000
# bedrooms         0.305046
# bathrooms        0.405898
# sqft_living      0.607379
# sqft_lot         0.083435
# floors           0.272151
# waterfront       0.073671
# view             0.196460
# condition        0.044926
# sqft_above       0.517395
# sqft_basement    0.221384
# yr_built         0.053012
# yr_renovated    -0.068447
# Name: price, dtype: float64

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(122)
sns.scatterplot(x='price',y='sqft_living',data=df,)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(122)
sns.scatterplot(x='price',y='sqft_above',data=df,)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_above'>

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(122)
sns.scatterplot(x='price',y='sqft_above',data=df,palette='viridis',hue='bedrooms')
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_above'>

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(122)
sns.scatterplot(x='price',y='sqft_above',data=df,palette='viridis',hue='condition')
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_above'>

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(122)
sns.scatterplot(x='price',y='sqft_above',data=df,palette='viridis',hue='floors')
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_above'>
