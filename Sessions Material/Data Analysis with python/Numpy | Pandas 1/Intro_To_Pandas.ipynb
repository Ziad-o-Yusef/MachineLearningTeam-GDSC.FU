# %%
import pandas as pd

# %%
data = [10,20,30,40,50,60]
df = pd.DataFrame(data, columns=['Numbers'])
df
# Out:
#    Numbers
# 0       10
# 1       20
# 2       30
# 3       40
# 4       50
# 5       60

# %%
data = [['tom', 10], ['nick', 15], ['juli', 14]]
  
df = pd.DataFrame(data, columns=['Name', 'Age'])

df
# Out:
#    Name  Age
# 0   tom   10
# 1  nick   15
# 2  juli   14

# %%
data = {'Name': ['Tom', 'nick', 'krish', 'jack'],
        'Age': [20, 21, 19, 18]}

df = pd.DataFrame(data)

df
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
data = {'Name': ['Tom', 'Jack', 'nick', 'juli'],
        'marks': [99, 98, 95, 90]}
  
df = pd.DataFrame(data, index=['rank1',
                               'rank2',
                               'rank3',
                               'rank4'])
  
df
# Out:
#        Name  marks
# rank1   Tom     99
# rank2  Jack     98
# rank3  nick     95
# rank4  juli     90

# %%
df = pd.read_csv("/content/df_befor_2008.csv")

# %%
df
# Out:
#        Unnamed: 0 CreditGrade  Term  LoanStatus  BorrowerAPR  BorrowerRate  \
# 0               0           C    36   Completed      0.16516        0.1580
# 1               2          HR    36   Completed      0.28269        0.2750
# 2              11           C    36   Completed      0.15033        0.1325
# 3              17          AA    36  Chargedoff      0.13202        0.1250
# 4              21           D    36   Completed      0.21488        0.2075
# ...           ...         ...   ...         ...          ...           ...
# 17383      113902           A    36   Completed      0.08805        0.0812
# 17384      113904           C    36  Chargedoff      0.24753        0.2400
# 17385      113914          HR    36   Defaulted      0.25757        0.2500
# 17386      113921          AA    36   Completed      0.18475        0.0400
# 17387      113926           E    36   Defaulted      0.29776        0.2900
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 CreditGrade  Term  LoanStatus  BorrowerAPR  BorrowerRate  \
# 0           0           C    36   Completed      0.16516        0.1580
# 1           2          HR    36   Completed      0.28269        0.2750
# 2          11           C    36   Completed      0.15033        0.1325
# 3          17          AA    36  Chargedoff      0.13202        0.1250
# 4          21           D    36   Completed      0.21488        0.2075
#
#    LenderYield  ListingCategory (numeric) BorrowerState       Occupation  ...  \
# 0       0.1380                          0            CO            Other  ...
# 1       0.2400                          0            GA            Other  ...
# 2       0.1225                          0            CA  Waiter/Waitress  ...
# 3       0.1175                          0            CA     Professional  ...
# 4       0.1975                          0            MI     Professional  ...
#
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0 CreditGrade  Term  LoanStatus  BorrowerAPR  BorrowerRate  \
# 0           0           C    36   Completed      0.16516        0.1580
# 1           2          HR    36   Completed      0.28269        0.2750
# 2          11           C    36   Completed      0.15033        0.1325
# 3          17          AA    36  Chargedoff      0.13202        0.1250
# 4          21           D    36   Completed      0.21488        0.2075
# 5          39           B    36   Completed      0.15211        0.1450
# 6          42          HR    36  Chargedoff      0.30300        0.2900
# 7          59           C    36   Completed      0.16717        0.1600
# 8          62           D    36  Chargedoff      0.23748        0.2300
# 9          63           D    36   Completed      0.29776        0.2900
#
#    LenderYield  ListingCategory (numeric) BorrowerState       Occupation  ...  \
# 0       0.1380                          0            CO            Other  ...
# ...

# %%
df.tail(10)
# Out:
#        Unnamed: 0 CreditGrade  Term  LoanStatus  BorrowerAPR  BorrowerRate  \
# 17378      113853           D    36   Completed      0.34770        0.3397
# 17379      113872          HR    36   Completed      0.30503        0.2894
# 17380      113880           C    36   Completed      0.15462        0.1475
# 17381      113890           C    36   Completed      0.15462        0.1475
# 17382      113891           E    36   Completed      0.19543        0.1808
# 17383      113902           A    36   Completed      0.08805        0.0812
# 17384      113904           C    36  Chargedoff      0.24753        0.2400
# 17385      113914          HR    36   Defaulted      0.25757        0.2500
# 17386      113921          AA    36   Completed      0.18475        0.0400
# 17387      113926           E    36   Defaulted      0.29776        0.2900
#
#        LenderYield  ListingCategory (numeric) BorrowerState  \
# 17378       0.3297                          1            CA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17388 entries, 0 to 17387
# Data columns (total 68 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          17388 non-null  int64
#  1   CreditGrade                         17388 non-null  object
#  2   Term                                17388 non-null  int64
#  3   LoanStatus                          17388 non-null  object
#  4   BorrowerAPR                         17388 non-null  float64
#  5   BorrowerRate                        17388 non-null  float64
#  6   LenderYield                         17388 non-null  float64
#  7   ListingCategory (numeric)           17388 non-null  int64
#  8   BorrowerState                       17388 non-null  object
#  9   Occupation                          17388 non-null  object
#  10  EmploymentStatus                    17388 non-null  object
# ...

# %%
df.shape
# Out:
# (17388, 68)

# %%
df.describe().T
# Out:
#                                       count          mean           std  \
# Unnamed: 0                          17388.0  57000.525017  32731.816804
# Term                                17388.0     36.000000      0.000000
# BorrowerAPR                         17388.0      0.190907      0.067403
# BorrowerRate                        17388.0      0.181506      0.066424
# LenderYield                         17388.0      0.170813      0.064573
# ListingCategory (numeric)           17388.0      0.066483      0.492606
# EmploymentStatusDuration            17388.0     52.768058     58.795912
# CreditScoreRangeLower               17388.0    630.425581    100.249775
# CreditScoreRangeUpper               17388.0    649.425581    100.249775
# CurrentCreditLines                  17388.0      8.727053      4.426600
# OpenCreditLines                     17388.0      7.476708      3.831467
# TotalCreditLinespast7years          17388.0     23.529101     13.849013
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CreditGrade', 'Term', 'LoanStatus', 'BorrowerAPR',
#        'BorrowerRate', 'LenderYield', 'ListingCategory (numeric)',
#        'BorrowerState', 'Occupation', 'EmploymentStatus',
#        'EmploymentStatusDuration', 'IsBorrowerHomeowner', 'CurrentlyInGroup',
#        'CreditScoreRangeLower', 'CreditScoreRangeUpper', 'CurrentCreditLines',
#        'OpenCreditLines', 'TotalCreditLinespast7years',
#        'OpenRevolvingAccounts', 'OpenRevolvingMonthlyPayment',
#        'InquiriesLast6Months', 'TotalInquiries', 'CurrentDelinquencies',
#        'AmountDelinquent', 'DelinquenciesLast7Years',
#        'PublicRecordsLast10Years', 'PublicRecordsLast12Months',
#        'RevolvingCreditBalance', 'BankcardUtilization',
#        'AvailableBankcardCredit', 'TotalTrades',
#        'TradesNeverDelinquent (percentage)', 'TradesOpenedLast6Months',
#        'IncomeRange', 'IncomeVerifiable', 'StatedMonthlyIncome',
# ...

# %%
# 'PublicRecordsLast12Months'
x  = df.PublicRecordsLast12Months

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
df['BorrowerAPR']
# Out:
# 0        0.16516
# 1        0.28269
# 2        0.15033
# 3        0.13202
# 4        0.21488
#           ...
# 17383    0.08805
# 17384    0.24753
# 17385    0.25757
# 17386    0.18475
# 17387    0.29776
# Name: BorrowerAPR, Length: 17388, dtype: float64

# %%
df['BorrowerAPR'].mean()
# Out:
# 0.19090725902921557

# %%
df['BorrowerAPR'].mode()
# Out:
# 0    0.29776
# Name: BorrowerAPR, dtype: float64

# %%
df['BorrowerAPR'].median()
# Out:
# 0.18475

# %%
df['BorrowerAPR'].max()
# Out:
# 0.51229

# %%
df['BorrowerAPR'].min()
# Out:
# 0.00653

# %%
df['BorrowerAPR'].std()
# Out:
# 0.06740303592323416

# %%
df['BorrowerAPR'].describe()
# Out:
# count    17388.000000
# mean         0.190907
# std          0.067403
# min          0.006530
# 25%          0.137050
# 50%          0.184750
# 75%          0.245020
# max          0.512290
# Name: BorrowerAPR, dtype: float64

# %%
df['BorrowerAPR'][1]
# Out:
# 0.28269

# %%
df.head()
# Out:
#    Unnamed: 0 CreditGrade  Term  LoanStatus  BorrowerAPR  BorrowerRate  \
# 0           0           C    36   Completed      0.16516        0.1580
# 1           2          HR    36   Completed      0.28269        0.2750
# 2          11           C    36   Completed      0.15033        0.1325
# 3          17          AA    36  Chargedoff      0.13202        0.1250
# 4          21           D    36   Completed      0.21488        0.2075
#
#    LenderYield  ListingCategory (numeric) BorrowerState       Occupation  ...  \
# 0       0.1380                          0            CO            Other  ...
# 1       0.2400                          0            GA            Other  ...
# 2       0.1225                          0            CA  Waiter/Waitress  ...
# 3       0.1175                          0            CA     Professional  ...
# 4       0.1975                          0            MI     Professional  ...
#
# ...

# %%
df.loc[2,'CreditGrade']
# Out:
# 'C'

# %%
df.iloc[0,2]
# Out:
# 36

# %%
df.corr()
# Out:
#                                     Unnamed: 0  Term  BorrowerAPR  \
# Unnamed: 0                            1.000000   NaN     0.003288
# Term                                       NaN   NaN          NaN
# BorrowerAPR                           0.003288   NaN     1.000000
# BorrowerRate                          0.002517   NaN     0.997121
# LenderYield                           0.002473   NaN     0.990509
# ListingCategory (numeric)            -0.000905   NaN    -0.000129
# EmploymentStatusDuration             -0.008350   NaN    -0.032970
# IsBorrowerHomeowner                   0.007941   NaN    -0.220682
# CurrentlyInGroup                     -0.004849   NaN     0.104657
# CreditScoreRangeLower                -0.001503   NaN    -0.646732
# CreditScoreRangeUpper                -0.001503   NaN    -0.646732
# CurrentCreditLines                    0.003293   NaN    -0.113904
# OpenCreditLines                       0.001010   NaN    -0.101823
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17388 entries, 0 to 17387
# Data columns (total 68 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          17388 non-null  int64
#  1   CreditGrade                         17388 non-null  object
#  2   Term                                17388 non-null  int64
#  3   LoanStatus                          17388 non-null  object
#  4   BorrowerAPR                         17388 non-null  float64
#  5   BorrowerRate                        17388 non-null  float64
#  6   LenderYield                         17388 non-null  float64
#  7   ListingCategory (numeric)           17388 non-null  int64
#  8   BorrowerState                       17388 non-null  object
#  9   Occupation                          17388 non-null  object
#  10  EmploymentStatus                    17388 non-null  object
# ...

# %%
df['IsBorrowerHomeowner'].value_counts()
# Out:
# False    10329
# True      7059
# Name: IsBorrowerHomeowner, dtype: int64

# %%
new_state_df = df[df['IsBorrowerHomeowner']==True]
new_state_df.head()
# Out:
#     Unnamed: 0 CreditGrade  Term  LoanStatus  BorrowerAPR  BorrowerRate  \
# 0            0           C    36   Completed      0.16516         0.158
# 3           17          AA    36  Chargedoff      0.13202         0.125
# 9           63           D    36   Completed      0.29776         0.290
# 11          68           E    36   Completed      0.21554         0.197
# 12          76           E    36   Completed      0.25861         0.250
#
#     LenderYield  ListingCategory (numeric) BorrowerState    Occupation  ...  \
# 0        0.1380                          0            CO         Other  ...
# 3        0.1175                          0            CA  Professional  ...
# 9        0.2850                          0            MO       Analyst  ...
# 11       0.1670                          0            CA  Nurse's Aide  ...
# 12       0.2450                          0            MO     Executive  ...
#
# ...

# %%
new_state_df['IsBorrowerHomeowner'].value_counts()
# Out:
# True    7059
# Name: IsBorrowerHomeowner, dtype: int64

# %%
new_state_df = df[df['IsBorrowerHomeowner']==True][['LoanStatus','Term']]
new_state_df.head()
# Out:
#     LoanStatus  Term
# 0    Completed    36
# 3   Chargedoff    36
# 9    Completed    36
# 11   Completed    36
# 12   Completed    36
