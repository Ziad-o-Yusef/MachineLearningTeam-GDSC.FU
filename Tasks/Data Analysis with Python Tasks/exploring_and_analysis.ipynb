# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(16,3))
plt.subplots_adjust(wspace=0.4)

plt.subplot(141) 
sns.countplot(x='sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# The number of male do the medical cost is greater than female

# %%
df['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
plt.figure(figsize=(16,3))
plt.subplots_adjust(wspace=0.4)

plt.subplot(142) 
sns.countplot(x='smoker', data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %% [markdown]
# The number of the smokers who  do Medical Cost is less than the number of non smokers who do

# %%
df['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
sns.countplot(x='region', data=df)
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %% [markdown]
# Residents of the South-East region are most in medical cost

# %%
df['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
sns.countplot(x='children', data=df)
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %% [markdown]
# The higher the number of children, the lower the proportion of the  medical cost

# %%
df['age'].value_counts()
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
plt.figure(figsize=(16,8))
plt.subplots_adjust(wspace=0.4, hspace=0.3)

plt.subplot(231) 
sns.histplot(x='age', data=df)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df['bmi'].value_counts()
# Out:
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64

# %%
sns.histplot(x='bmi', data=df)
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
df['charges'].value_counts()
# Out:
# 1639.56310     2
# 16884.92400    1
# 29330.98315    1
# 2221.56445     1
# 19798.05455    1
#               ..
# 7345.08400     1
# 26109.32905    1
# 28287.89766    1
# 1149.39590     1
# 29141.36030    1
# Name: charges, Length: 1337, dtype: int64

# %%
sns.histplot(x='charges', data=df)
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(122)
sns.scatterplot(x='age',y='charges',data=df,palette='viridis',hue='bmi')
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(122)
sns.scatterplot(x='age',y='charges',data=df,palette='viridis',hue='smoker')
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(122)
sns.scatterplot(x='age',y='charges',data=df,palette='viridis',hue='region')
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
plt.figure(figsize=(16,3))
plt.subplots_adjust(wspace=0.4)
 
plt.subplot(144) 
sns.scatterplot(x='bmi', y='charges', hue='smoker', data=df)
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
fig = sns.kdeplot(df['age'], shade=True, color="y")
# Out:
# <ipython-input-53-2c2e3bb523bd>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   fig = sns.kdeplot(df['age'], shade=True, color="y")

# %%
plt.figure(figsize = (20,10))
ax2 = sns.countplot(hue="region", x='sex', data=df )
ax2.set_ylabel("Count", fontsize=17)
plt.show()

# %%
plt.figure(figsize = (20,10))
ax2 = sns.countplot(hue="sex", x='smoker', data=df )
ax2.set_ylabel("Count", fontsize=17)
plt.show()

# %%
df.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
df.corr()['age']
# Out:
# age         1.000000
# bmi         0.109272
# children    0.042469
# charges     0.299008
# Name: age, dtype: float64

# %%
corr = df.corr()  
plt.figure(figsize=(10,10))   
sns.heatmap(corr, annot=True, cmap='coolwarm', cbar=True, fmt='.2f', square=True)
plt.title('Features Correlation Matrix', fontsize=16)
plt.xlabel('Features', fontsize=12)
plt.ylabel('Features', fontsize=12)
# Out:
# Text(95.72222222222221, 0.5, 'Features')
